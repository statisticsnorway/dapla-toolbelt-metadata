# %% [markdown]
# # Variable definitions

# %% [markdown]
# ## Set up

# %%
from dapla_metadata.variable_definitions.vardef import Vardef
from dapla_metadata.variable_definitions.generated.vardef_client.models.draft import Draft
from datetime import date
import os

# %%
# If necessary check token
from dapla_metadata.variable_definitions.config import get_vardef_host


print(os.environ.get("OIDC_TOKEN"))
print(get_vardef_host())
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJxcWFrV3FDVWwtc2xaVVQ3dkVVemUxSmYxMHZXanFFbWZ0VGNIN0FzQlVzIn0.....kwIW3Ds4ZKmB7t58MG8WondFYJdycSoOVCKnpbQ3HIVOwQ3s_N9khiVaHief5_zS5IbHJ16D80EnUhuu9a7hR0CI7yB1BPs9bhuG7yc7JoJ2oh9a6Hax1IowPFVK6LY8miF3qPotj6CE1gzeDPG6mslEWBySiUY-lo9kAJpMrKMLGDkRKyLKSrum5YrM6C1KGKambhmJ7ZFd2jHdpUABYXyROqZu_2mBnVtm0ac2oQs_F7iaCbhlN2P5oq7Hl_x7C9VjwhopKOFBUMIkY3Nv23wneb-1GUf9La2qd0S3VFQLHHrNZMAnuiK7L94M325tZrxIcRUat6pPcdlciQ1sDA
# http://localhost:8080

# %%
### data for creating a draft variable definition
### Run this for validating your data

draft = Draft(
    name = {
        "nb": "",
        "nn": "",
        "en": "",
    },
    short_name= "fin",
    definition= {
        "nb": "",
        "nn": "",
        "en": "",
    },
    classification_reference="91",
    unit_types=[
        "01",
    ],
    subject_fields=[
        "al",
    ],
    contains_special_categories_of_personal_data=False,
    measurement_type=None,
    valid_from=date(2024,12,18),
    external_reference_uri=None,
    comment=None,
    related_variable_definition_uris=None,
    contact=None,
)

# %%
### Create draft variable definition and save in a variable

my_draft = Vardef.create_draft(draft)

# %%
print(my_draft)
# Out:
# id='VgIgf4Bb' patch_id=1 name={'nb': '', 'nn': '', 'en': ''} short_name='fin' definition={'nb': '', 'nn': '', 'en': ''} classification_reference='91' unit_types=['01'] subject_fields=['al'] contains_special_categories_of_personal_data=False variable_status=<VariableStatus.DRAFT: 'DRAFT'> measurement_type=None valid_from=datetime.date(2024, 12, 18) valid_until=None external_reference_uri=None comment=None related_variable_definition_uris=None owner={'team': 'dapla-felles', 'groups': ['dapla-felles-developers']} contact=None created_at=datetime.datetime(2024, 12, 18, 11, 25, 23, 493487) created_by=None last_updated_at=datetime.datetime(2024, 12, 18, 11, 25, 23, 493487) last_updated_by=None
